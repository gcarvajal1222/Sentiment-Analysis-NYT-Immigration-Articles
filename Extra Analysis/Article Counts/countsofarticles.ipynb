# %%
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings 
import nltk
#from gensim.models import Word2Vec 
#from gensim.models.wrappers import FastText 

#from gensim.models import FastText



from IPython.display import clear_output, display

from nltk.tokenize import sent_tokenize, word_tokenize 
import warnings 
import nltk 
import pandas as pd
from pandas import *
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
import re
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer() 
import re
from sklearn.feature_extraction import text
from builtins import input
from statistics import mean
from nltk import  pos_tag_sents


from statistics import mode, StatisticsError

import functools


import re
from sklearn.feature_extraction import text
global cases

from pandas import ExcelWriter
import xlsxwriter

import xlwt
from xlwt.Workbook import *


from nltk.corpus import wordnet

from statistics import *

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import numpy as np
import pandas as pd
import re
from nltk import pos_tag
from nltk.tokenize.treebank import TreebankWordDetokenizer
import seaborn as sns

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\gabri\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\gabri\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\gabri\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
df = pd.read_excel("USNewsArticles.xlsx")

# %%
df
# Out:
#       response.docs.pub_date status  \
# 0                 1981-01-03     OK
# 1                 1981-01-04     OK
# 2                 1981-01-04     OK
# 3                 1981-01-04     OK
# 4                 1981-01-04     OK
# ...                      ...    ...
# 11653             2019-12-23     OK
# 11654             2019-12-23     OK
# 11655             2019-12-24     OK
# 11656             2019-12-30     OK
# 11657             2019-12-31     OK
#
#                                                copyright  \
# 0      Copyright (c) 2020 The New York Times Company....
# 1      Copyright (c) 2020 The New York Times Company....
# 2      Copyright (c) 2020 The New York Times Company....
# 3      Copyright (c) 2020 The New York Times Company....
# 4      Copyright (c) 2020 The New York Times Company....
# ...                                                  ...
# 11653  Copyright (c) 2020 The New York Times Company....
# 11654  Copyright (c) 2020 The New York Times Company....
# ...

# %%
df['response.docs.pub_date'].groupby([df["response.docs.pub_date"], df["response.docs.pub_date"]]).agg('count')
# Out:
# response.docs.pub_date  response.docs.pub_date
# 1981-01-03              1981-01-03                1
# 1981-01-04              1981-01-04                5
# 1981-01-06              1981-01-06                1
# 1981-01-07              1981-01-07                1
# 1981-01-08              1981-01-08                2
#                                                  ..
# 2019-12-18              2019-12-18                1
# 2019-12-23              2019-12-23                2
# 2019-12-24              2019-12-24                1
# 2019-12-30              2019-12-30                1
# 2019-12-31              2019-12-31                1
# Name: response.docs.pub_date, Length: 7036, dtype: int64

# %%
# Out:
# response.docs.pub_date
#     response.docs.pub_date  response.docs.pub_date...
# Name: response.docs.pub_date, dtype: object

# %%
monthly_counts=df['response.docs.pub_date'].groupby([df['response.docs.pub_date'].dt.year.rename('year'), df['response.docs.pub_date'].dt.month.rename('month')]).agg({'count'})

# %%
yearly_counts=df['response.docs.pub_date'].groupby([df['response.docs.pub_date'].dt.year.rename('year')]).agg({'count'})

# %%
with pd.ExcelWriter('US_News_Articles_counts.xlsx') as writer:
    monthly_counts.to_excel(writer, sheet_name = 'monthly_counts', header = True )
    yearly_counts.to_excel(writer, sheet_name = 'yearly_counts', header = True )

# %%
df['response.docs.pub_date'].groupby([df['response.docs.pub_date'].dt.year.rename('year')]).agg({'count'})
# Out:
#       count
# year
# 1981    371
# 1982    276
# 1983    199
# 1984    203
# 1985    258
# 1986    316
# 1987    255
# 1988    170
# 1989    196
# 1990    159
# 1991    178
# 1992    147
# 1993    220
# 1994    266
# 1995    239
# 1996    276
# 1997    316
# 1998    248
# 1999    277
# 2000    242
# 2001    320
# 2002    312
# 2003    268
# 2004    272
# 2005    283
# 2006    772
# 2007    594
# 2008    280
# 2009    278
# 2010    289
# 2011    239
# 2012    263
# 2013    389
# 2014    347
# 2015    373
# 2016    285
# 2017    429
# 2018    490
# 2019    363

# %%
df_Latino = pd.read_excel("US_Latino_News_Articles.xlsx")

# %%
monthly_counts=df_Latino['response.docs.pub_date'].groupby([df_Latino['response.docs.pub_date'].dt.year.rename('year'), df_Latino['response.docs.pub_date'].dt.month.rename('month')]).agg({'count'})

# %%
yearly_counts=df_Latino['response.docs.pub_date'].groupby([df_Latino['response.docs.pub_date'].dt.year.rename('year')]).agg({'count'})

# %%
with pd.ExcelWriter('US_Latino_News_Articles_counts.xlsx') as writer:
    monthly_counts.to_excel(writer, sheet_name = 'monthly_counts', header = True )
    yearly_counts.to_excel(writer, sheet_name = 'yearly_counts', header = True )

# %% [markdown]
# # Quartely counts

# %%
quarterly_counts_df_Latino=df_Latino['response.docs.pub_date'].groupby([df_Latino['response.docs.pub_date'].dt.year.rename('year'), df_Latino['response.docs.pub_date'].dt.quarter.rename('month')]).agg({'count'})

# %%
quarterly_counts_df_Latino
# Out:
#             count
# year month
# 1981 1         26
#      2         45
#      3         60
#      4         51
# 1982 1         24
# ...           ...
# 2018 4         25
# 2019 1         14
#      2         29
#      3         20
#      4          8
#
# [156 rows x 1 columns]

# %%
quarterly_counts_US = df['response.docs.pub_date'].groupby([df['response.docs.pub_date'].dt.year.rename('year'), df['response.docs.pub_date'].dt.quarter.rename('quarter')]).agg({'count'})

# %%
# Out:
#               count
# year quarter
# 1981 1           84
#      2           80
#      3          111
#      4           96
# 1982 1           68
# ...             ...
# 2018 4          105
# 2019 1           72
#      2          117
#      3          105
#      4           69
#
# [156 rows x 1 columns]

# %%
with pd.ExcelWriter('Quarterly_counts_Data.xlsx') as writer:
    quarterly_counts_df_Latino.to_excel(writer, sheet_name = 'quarterly_counts_latino', header = True )
    quarterly_counts_US.to_excel(writer, sheet_name = 'quarterly_count_US', header = True )
