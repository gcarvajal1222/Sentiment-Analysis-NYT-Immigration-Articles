# %%
import requests
import json
import pandas as pd

# %%
from yanytapi import SearchAPI
api = SearchAPI("a0HA3uBISDkGyvUGR3FeoAGybtDVPPM5")

# %%
obama = api.search(' ', fq={"lead_paragraph": "immigration", 
                              "source": ["Reuters", 
                                         "AP", 
                                         "The New York Times"]}, 
                          begin_date="20190101",end_date = '20190201',
                    
                          facet_filter=True)

# %%
obama['response']['meta']['hits']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-d380c88d3806> in <module>
# ----> 1 obama['response']['meta']['hits']
#
# TypeError: 'Results' object is not subscriptable

# %%
users_locs = [[article._id, article.document_type, article.lead_paragraph] for article in obama]
df = pd.DataFrame(data=users_locs, columns=['ID', 'type', 'lead_paragraph'])
df
# Out:
#                                                    ID        type  \
# 0   nyt://article/ed699717-7e47-5ff1-9ebb-3f3253ab...     article
# 1   nyt://article/5e369f54-227a-5634-bf2b-0afa1c49...     article
# 2   nyt://article/98b04a4f-9fca-5d15-9396-81a51cd9...     article
# 3   nyt://article/ba4a9b04-6259-5127-abd2-9a57486e...     article
# 4   nyt://article/26aee850-3df0-5916-83fa-0dd0b467...     article
# 5    nyt://video/01aabe63-d55b-53ba-9980-968bba0d182a  multimedia
# 6   nyt://article/8d9f99dd-cb9d-5bcc-80b9-7c3878e5...     article
# 7    nyt://video/80c61cd6-294b-52de-b426-30eabf4ad073  multimedia
# 8    nyt://video/3ccab4b6-c51c-5237-b1c0-1c50ba43b904  multimedia
# 9   nyt://article/6900cc67-3ae2-5e8b-9cbd-666c933c...     article
# 10  nyt://article/9b6e2016-0394-5828-be9c-a7ac7a70...     article
# 11   nyt://video/1f149b63-aab3-5306-8f1b-af40a26a3566  multimedia
# 12  nyt://article/3de5974f-8a59-55b7-a84d-402a7bf4...     article
# 13  nyt://article/8985d375-91b6-55b3-855e-34501937...     article
# 14  nyt://article/2ce1dfe7-2fe2-5407-8b9e-ad16a796...     article
# 15  nyt://article/50b18dfb-8440-543c-9799-3693d410...     article
# 16  nyt://article/9e5851af-8bf2-57fa-a4e3-79f370ab...     article
# 17  nyt://article/a65fb2bb-bd69-52b6-a19d-da6f606d...     article
# 18  nyt://interactive/d5a1103d-383b-5cd4-b12e-9625...  multimedia
# 19   nyt://video/3e7f4963-82ee-53c5-a8a1-28f23a9cff97  multimedia
#
#                                        lead_paragraph
# 0   The federal government said this week it had e...
# 1   As the fight continues over President Trump’s ...
# 2   PALERMO, Sicily — Italy’s populist interior mi...
# 3   Immigration officials have been force-feeding ...
# 4   As an immigrant living in Arizona, a state tha...
# 5   As the battle over U.S. immigration policy and...
# 6   A 61-year-old man from the Dominican Republic ...
# 7   During his visit to Texas near the border with...
# 8   President Trump told farmers that the pain the...
# 9   It’s no mere coincidence that Jeffrey R. Brown...
# 10  HONG KONG — A Belarusian escort who has spent ...
# 11  Building a border wall, ending birthright citi...
# 12  President Trump has shut down the government t...
# 13  President Trump seems to think that his hard-l...
# 14  LONDON — A group of 49 migrants stranded at se...
# 15  WASHINGTON — America will get its first taste ...
# 16  WASHINGTON — The fate of President Trump’s $5....
# 17  Racism, homophobia, sexism, police violence, i...
# 18  The number of pending immigration cases has gr...
# 19  Senator Kamala Harris of California kicked off...
